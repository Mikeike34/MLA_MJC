# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikeike34/MLA_MJC/blob/main/MLA1_MJC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Machine Learning Assignment 1**<br>
# **Michael Cantone**<br>
# **CS430-ON**<br>
# **Machine Learning in the Cloud**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/CS430/weather_2012.csv')

# %% [markdown]
# ##<u>Displaying the first 5 rows of the dataframe</u>

# %%
df.head(5)
# Out:
#        Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0  1/1/2012 0:00      -1.8                -3.9           86                4
# 1  1/1/2012 1:00      -1.8                -3.7           87                4
# 2  1/1/2012 2:00      -1.8                -3.4           89                7
# 3  1/1/2012 3:00      -1.5                -3.2           88                6
# 4  1/1/2012 4:00      -1.5                -3.3           88                7
#
#    Visibility (km)  Stn Press (kPa)               Weather
# 0              8.0           101.24                   Fog
# 1              8.0           101.24                   Fog
# 2              4.0           101.26  Freezing Drizzle,Fog
# 3              4.0           101.27  Freezing Drizzle,Fog
# 4              4.8           101.23                   Fog

# %% [markdown]
# ##<u>Displaying the last 5 rows of the dataframe</u>

# %%
df.tail(5)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  12/31/2012 19:00       0.1                -2.7           81
# 8780  12/31/2012 20:00       0.2                -2.4           83
# 8781  12/31/2012 21:00      -0.5                -1.5           93
# 8782  12/31/2012 22:00      -0.2                -1.8           89
# 8783  12/31/2012 23:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %% [markdown]
# ##<u>Displaying a sample of 5 rows from the dataframe</u>

# %%
df.sample(5)
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 7521   11/9/2012 9:00       1.3                -2.4           76
# 1065   2/14/2012 9:00     -11.6               -18.0           59
# 6916  10/15/2012 4:00      11.9                10.7           92
# 5394  8/12/2012 18:00      23.2                18.6           75
# 5917   9/3/2012 13:00      26.2                10.0           36
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 7521               17             48.3           101.34  Mostly Cloudy
# 1065                4             24.1           101.12   Mainly Clear
# 6916                4             12.9            99.66  Mostly Cloudy
# 5394               15             48.3           100.61   Mainly Clear
# 5917                4             48.3           101.50   Mainly Clear

# %% [markdown]
# ##<u>Displaying the column values and renaming them to better fit their use </u>

# %%
print(df.columns.values)
# Out:
# ['Date/Time' 'Temp (C)' 'Dew Point Temp (C)' 'Rel Hum (%)'
#  'Wind Spd (km/h)' 'Visibility (km)' 'Stn Press (kPa)' 'Weather']

# %%
df.rename(columns={'Date/Time':'date_time','Temp (C)':'temp_c','Dew Point Temp (C)':'dew_point','Rel Hum (%)':'relative_humidity','Wind Spd (km/h)':'wind_speed','Visibility (km)':'visibility','Stn Press (kPa)':'pressure','Weather':'weather'}, inplace=True)

# %%
df.describe()
# Out:
#             temp_c    dew_point  relative_humidity   wind_speed   visibility  \
# count  8784.000000  8784.000000        8784.000000  8784.000000  8784.000000
# mean      8.798144     2.555294          67.431694    14.945469    27.664447
# std      11.687883    10.883072          16.918881     8.688696    12.622688
# min     -23.300000   -28.500000          18.000000     0.000000     0.200000
# 25%       0.100000    -5.900000          56.000000     9.000000    24.100000
# 50%       9.300000     3.300000          68.000000    13.000000    25.000000
# 75%      18.800000    11.800000          81.000000    20.000000    25.000000
# max      33.000000    24.400000         100.000000    83.000000    48.300000
#
#           pressure
# count  8784.000000
# mean    101.051623
# std       0.844005
# min      97.520000
# 25%     100.560000
# 50%     101.070000
# 75%     101.590000
# max     103.650000

# %% [markdown]
# ##<u>Adding column ' temp_f ' to the data frame</u>

# %%
df['temp_f'] = (df['temp_c'] * 9/5) + 32

# %% [markdown]
# ##<u>Rearranging the order of the columns so that ' temp_f ' is before ' temp_c '</u>

# %%
df = df[['date_time','temp_f','temp_c','dew_point','relative_humidity','wind_speed','visibility','pressure','weather']]

# %%
df.head()
# Out:
#        date_time  temp_f  temp_c  dew_point  relative_humidity  wind_speed  \
# 0  1/1/2012 0:00   28.76    -1.8       -3.9                 86           4
# 1  1/1/2012 1:00   28.76    -1.8       -3.7                 87           4
# 2  1/1/2012 2:00   28.76    -1.8       -3.4                 89           7
# 3  1/1/2012 3:00   29.30    -1.5       -3.2                 88           6
# 4  1/1/2012 4:00   29.30    -1.5       -3.3                 88           7
#
#    visibility  pressure               weather
# 0         8.0    101.24                   Fog
# 1         8.0    101.24                   Fog
# 2         4.0    101.26  Freezing Drizzle,Fog
# 3         4.0    101.27  Freezing Drizzle,Fog
# 4         4.8    101.23                   Fog

# %% [markdown]
# ##<u>The data types of each column in the data frame</u>

# %%
df.dtypes
# Out:
# date_time             object
# temp_f               float64
# temp_c               float64
# dew_point            float64
# relative_humidity      int64
# wind_speed             int64
# visibility           float64
# pressure             float64
# weather               object
# dtype: object

# %% [markdown]
# ##<u>Converting ' date_time ' column to an actual datetime data type</u>

# %%
df['date_time'] = pd.to_datetime(df['date_time'])
df.date_time.dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ##<u>Created a pandas series of the monthly average temperature in fahrenheit</u>

# %%
monthly_avg = df.groupby(pd.Grouper(key='date_time', freq='ME'))['temp_f'].mean()
monthly_avg = pd.Series(monthly_avg)
monthly_avg
# Out:
# date_time
# 2012-01-31    18.731290
# 2012-02-29    24.395000
# 2012-03-31    37.618226
# 2012-04-30    44.616750
# 2012-05-31    61.227984
# 2012-06-30    68.241250
# 2012-07-31    73.022097
# 2012-08-31    72.102742
# 2012-09-30    61.672000
# 2012-10-31    51.718952
# 2012-11-30    33.676500
# 2012-12-31    26.048629
# Freq: ME, Name: temp_f, dtype: float64

# %% [markdown]
# ##<u>Displaying a scatter plot that compares temperature and relative humidity</u>

# %%
df.plot(kind='scatter', x='temp_f',y='relative_humidity',figsize=(20,10))
# Out:
# <Axes: xlabel='temp_f', ylabel='relative_humidity'>

# %% [markdown]
# ##<u>Displaying a line graph that represents the monthly average temperature in fahrenheit</u>

# %%
monthly_avg.plot(kind="line",color="red",figsize=(20,10))
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# ##<u>Displaying a boxplot of the entire dataframe</u>

# %%
df.plot(kind="box",figsize=(20,10))
# Out:
# <Axes: >
